# %%
import pandas as pd 

df=pd.read_csv("C:\\Users\\I\\Downloads\\weather_data.csv")

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.set_index('day')
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.set_index('day', inplace=True)

# %%
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
df.loc['1/1/2017']
# Out:
# temperature      32
# windspeed         6
# event          Rain
# Name: 1/1/2017, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.head(4)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow

# %%
df.tail(1)
# Out:
#         day  temperature  windspeed  event
# 5  1/6/2017           31          2  Sunny

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
g=df.groupby('event')

# %%
g

# %%
for x,y in g:
 print(x)
 print(y)
 print()
# Out:
# Rain
#         day  temperature  windspeed event
# 0  1/1/2017           32          6  Rain
# 4  1/5/2017           32          4  Rain
#
# Snow
#         day  temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow
#
# Sunny
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
g.get_group('Snow')
# Out:
#         day  temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow

# %%
g.mean()
# Out:
#        temperature  windspeed
# event
# Rain          32.0        5.0
# Snow          26.0        4.5
# Sunny         33.0        4.5

# %%
g.max()
# Out:
#             day  temperature  windspeed
# event
# Rain   1/5/2017           32          6
# Snow   1/4/2017           28          7
# Sunny  1/6/2017           35          7

# %%
g.min()
# Out:
#             day  temperature  windspeed
# event
# Rain   1/1/2017           32          4
# Snow   1/3/2017           24          2
# Sunny  1/2/2017           31          2

# %%
# %matplotlib inline
g.plot()
# Out:
# event
# Rain     AxesSubplot(0.125,0.125;0.775x0.755)
# Snow     AxesSubplot(0.125,0.125;0.775x0.755)
# Sunny    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
df.replace(to_replace='Rain',value=2)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6      2
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4      2
# 5  1/6/2017           31          2  Sunny

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.replace({'event':["Sunny", "Snow"]
    
    
},3)
# Out:
#         day  temperature  windspeed event
# 0  1/1/2017           32          6  Rain
# 1  1/2/2017           35          7     3
# 2  1/3/2017           28          2     3
# 3  1/4/2017           24          7     3
# 4  1/5/2017           32          4  Rain
# 5  1/6/2017           31          2     3

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.replace({
    "event": "[A-Za-z]"}, "Nan" ,regex=True
    
)
# Out:
#         day  temperature  windspeed            event
# 0  1/1/2017           32          6     NanNanNanNan
# 1  1/2/2017           35          7  NanNanNanNanNan
# 2  1/3/2017           28          2     NanNanNanNan
# 3  1/4/2017           24          7     NanNanNanNan
# 4  1/5/2017           32          4     NanNanNanNan
# 5  1/6/2017           31          2  NanNanNanNanNan

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny
